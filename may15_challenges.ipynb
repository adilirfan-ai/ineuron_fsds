# %%
s = "this is My First Python programming class and i am learNING python string and its function"
print(s[1:300:3])
# Out:
# h   r tnrrmglsnimeNGyosi dtfco

# %%
#Reverse the string without using reverse function
print(s[::-1])
# Out:
# noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht

# %%
# Try to split a string after conversion of entire string in uppercase
upper_case = s.upper()
split_ = upper_case.split(' ')
print(split_)
# Out:
# ['THIS', 'IS', 'MY', 'FIRST', 'PYTHON', 'PROGRAMMING', 'CLASS', 'AND', 'I', 'AM', 'LEARNING', 'PYTHON', 'STRING', 'AND', 'ITS', 'FUNCTION']

# %%
# Try to convert the whole string into lower case
lower_case = s.lower()
print(lower_case)
# Out:
# this is my first python programming class and i am learning python string and its function

# %%
#Try to capitalize the whole string
capitalize_ = s.capitalize()
print(capitalize_)
# Out:
# This is my first python programming class and i am learning python string and its function

# %%
#Write a diference between isalnum() and isalpha()

# %%
# Replace a string character by another charactor by taking your own example 
"sudhanshu"
a = 'sudhanshu'
a = a.replace('sudhanshu', 'adil')
print(a)
# Out:
# adil
