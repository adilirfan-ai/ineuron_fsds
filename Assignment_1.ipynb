# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators?
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# Ans:values: 'hello', 6, 87.8
#     expression: *, -, /, +

# %% [raw]
# 2. What is the difference between string and variable?
# Ans: A string is a sequence of characters.
#      A Python variable is a reserved memory location to store values and  that is a reference or pointer to an object.

# %% [raw]
# 3. Describe three different data types?
# Ans:1)String- A string is a sequence of characters.
#     2)Boolean- It represent either True or False.
#     3)Int- The int data type to represent whole integer values.
#     4)Float- To represent floating-point values or decimal values

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
# Ans: An expression is made up of operators and operands that is interpreted to produce some other value.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
# Ans:

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# Ans: 23

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam'* 3
# Ans: 'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?
# Ans: Valid variable name may contain letters, digits (0-9) or the underscore character _

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [raw]
# #10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 + 'burritos'
# Ans: Python is strong type language. It only concatenate string.
#     'I have eaten' + '99' + 'burritos'
